# %%
#load and plot USGS peakflow data
import pandas as pd

# %%
pd.read_table("Napa_daily_dvstat.txt", skiprows=45)
# Out:
#    agency_cd   site_no parameter_cd dd_nu month_nu day_nu begin_yr end_yr  \
# 0         5s       15s           5s   11n       3n     3n       6n     6n
# 1       USGS  11458000        00060     2        1      1     1960   2013
# 2       USGS  11458000        00060     2        1      2     1960   2013
# 3       USGS  11458000        00060     2        1      3     1960   2013
# 4       USGS  11458000        00060     2        1      4     1960   2013
# 5       USGS  11458000        00060     2        1      5     1960   2013
# 6       USGS  11458000        00060     2        1      6     1960   2013
# 7       USGS  11458000        00060     2        1      7     1960   2013
# 8       USGS  11458000        00060     2        1      8     1960   2013
# 9       USGS  11458000        00060     2        1      9     1960   2013
# 10      USGS  11458000        00060     2        1     10     1960   2013
# 11      USGS  11458000        00060     2        1     11     1960   2013
# ...

# %%
#Go to USGS website 
#http://waterdata.usgs.gov/ca/nwis/dvstat?&site_no=11458000&agency_cd=USGS&por_11458000_2=2209953,00060,2,1929-10-01,2013-10-27&por_11458000_5=2209953,80155,5,1976-10-01,1978-09-30&stat_cds=mean_va&referred_module=sw&format=html_table
#
